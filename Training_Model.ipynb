# %%
# !pip install ultralytics
import ultralytics
ultralytics.checks()
# Out:
# Ultralytics 8.3.234 🚀 Python-3.12.12 torch-2.9.0+cu126 CUDA:0 (Tesla T4, 15095MiB)
# Setup complete ✅ (2 CPUs, 12.7 GB RAM, 38.4/112.6 GB disk)

# %%
# !pip install roboflow

from roboflow import Roboflow
rf = Roboflow(api_key="itqfRRQTIUw3rB4PUR5J")
project = rf.workspace("shubham-vishwakarma-5olb4").project("fire-smoke-detection-gtgmn")
version = project.version(2)
dataset = version.download("yolov8")
# Out:
# ...
# loading Roboflow workspace...
# loading Roboflow project...

# %%
# !yolo task=detect mode=train model=yolov8n.pt data={dataset.location}/data.yaml epochs=25 imgsz=640 plots=True
# Out:
# ...
# Ultralytics 8.3.234 🚀 Python-3.12.12 torch-2.9.0+cu126 CUDA:0 (Tesla T4, 15095MiB)
# ...

# %%
# !yolo task=detect mode=predict model=/content/runs/detect/train/weights/best.pt source=test_video.mp4 save=True
# Out:
# Ultralytics 8.3.234 🚀 Python-3.12.12 torch-2.9.0+cu126 CUDA:0 (Tesla T4, 15095MiB)
# Model summary (fused): 72 layers, 3,006,038 parameters, 0 gradients, 8.1 GFLOPs
#
# video 1/1 (frame 1/347) /content/test_video.mp4: 384x640 (no detections), 77.1ms
# video 1/1 (frame 2/347) /content/test_video.mp4: 384x640 (no detections), 11.6ms
# video 1/1 (frame 3/347) /content/test_video.mp4: 384x640 (no detections), 7.6ms
# video 1/1 (frame 4/347) /content/test_video.mp4: 384x640 (no detections), 10.4ms
# video 1/1 (frame 5/347) /content/test_video.mp4: 384x640 (no detections), 7.7ms
# video 1/1 (frame 6/347) /content/test_video.mp4: 384x640 (no detections), 7.1ms
# video 1/1 (frame 7/347) /content/test_video.mp4: 384x640 (no detections), 7.5ms
# video 1/1 (frame 8/347) /content/test_video.mp4: 384x640 (no detections), 8.2ms
# video 1/1 (frame 9/347) /content/test_video.mp4: 384x640 (no detections), 7.6ms
# video 1/1 (frame 10/347) /content/test_video.mp4: 384x640 (no detections), 7.4ms
# ...
